# %%
import pandas as pd
from pathlib import Path

base = Path.cwd().parent
df = pd.read_parquet(base / "data" / "spy_daily.parquet")
df.tail()
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker             SPY         SPY         SPY         SPY        SPY
# Date
# 2026-03-24  653.179993  657.030029  649.880005  651.320007   96457500
# 2026-03-25  656.820007  660.890015  654.239990  658.669983   90653800
# 2026-03-26  645.090027  654.849976  644.820007  652.059998   96494400
# 2026-03-27  634.090027  642.659973  633.109985  642.500000  102725900
# 2026-03-30  631.969971  640.369995  629.289978  640.109985   92476229
